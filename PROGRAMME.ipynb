# %%
print("anuradha")
# Out:
# anuradha

# %%
fruits=["Apple","Banana","orange","grapes"]
for fruit in fruits:
    print(fruit)
# Out:
# Apple
# Banana
# orange
# grapes

# %%
import matplotlib.pyplot as plt

# %%
X=[1,2,3,4,5]
Y=[2,4,6,8,10]

# %%
plt.plot(X,Y)
plt.title("simple line plot")
plt.xlabel("X-asis")
plt.ylabel("Y-asis")
plt.show()
